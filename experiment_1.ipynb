# %% [markdown]
# <a href="https://colab.research.google.com/github/benskrba2529-hash/S2-lab/blob/main/experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###EXPERIMENT 1:
# INTRODUCING PYTTHON AS A TOOL FOR COMPUTATING MATHEMATICS

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %% [markdown]
# 2,BASIC ARITHMETIC OPERATOR

# %%
#ADDITION
A=10
B=3
print("ADDITION",A+B)
#SUBTRACTION
print("SUBTRACTION",A-B)
#MULTIPLICATION
print("MULTIPLICATION",A*B)
#DIVISION
print("DIVISION",A/B)
#FLOOR DIVISION
print("FLOOR DIVISION",A//B)
#MODULUS
print("MODULUS",A%B)
#EXPONENTIATION
print("EXPONENTIATION",A**B)
# Out:
# ADDITION 13
# SUBTRACTION 7
# MULTIPLICATION 30
# DIVISION 3.3333333333333335
# FLOOR DIVISION 3
# MODULUS 1
# EXPONENTIATION 1000

# %% [markdown]
# 3,VARIABLES AND DATA TYPES

# %%
#INTEGER
x=10
print("integer:",x)
#float
y=3.14
print("float:",y)
#string
z="python"
print("string:",z)
type(z)
# Out:
# integer: 10
# float: 3.14
# string: python
# str

# %% [markdown]
# ## 4. Lists

# %%
#creating a LOOP
fruits=["apple","banana","cherry"]
print("lists:",fruits)
#accesing an element
print("first fruit:",fruits[0])
#adding an element
fruits.append("orange")
print("updated list:",fruits)
#removing an element
fruits.remove("banana")
print("updated list:",fruits)
# Out:
# lists: ['apple', 'banana', 'cherry']
# first fruit: apple
# updated list: ['apple', 'banana', 'cherry', 'orange']
# updated list: ['apple', 'cherry', 'orange']

# %% [markdown]
# ##5.Loop

# %%
#for loop
for i in range (5):
  print("for loop iteration:",i)
# Out:
# for loop iteration: 0
# for loop iteration: 1
# for loop iteration: 2
# for loop iteration: 3
# for loop iteration: 4
